# %%
import os
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np
import torch
from src.load_data import get_dataloaders
import torchvision

# %%
batch_size = 4
trainloader, valloader, _ = get_dataloaders(ev='P', batch_size=batch_size)

# %%
# visualize a batch of images
def show_batch(img_batch):
    plt.figure(figsize=(12, 18))
    grid = torchvision.utils.make_grid(img_batch)
    plt.imshow(grid.numpy().transpose((1, 2, 0)))
    plt.title("Batch from dataloader")

# get a batch of training data
inputs, classes = next(iter(trainloader))

# show images
show_batch(inputs)

# %%
# visualize a batch of images
def show_batch(img_batch):
    plt.figure(figsize=(12, 18))
    grid = torchvision.utils.make_grid(img_batch)
    plt.imshow(grid.numpy().transpose((1, 2, 0)))
    plt.title("Batch from dataloader")

# get a batch of training data
inputs, classes = next(iter(valloader))

# show images
show_batch(inputs)
